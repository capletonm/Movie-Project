# %%
import pandas as pd

# %%
df = pd.read_excel("UserReviewsClean43LIWC.xlsx")

df.head()
# Out:
#                                         url idvscore         reviewer  \
# 0  https://www.metacritic.com/movie/bronson        8   'Longbottom94'
# 1  https://www.metacritic.com/movie/bronson        9        'MartinB'
# 2  https://www.metacritic.com/movie/bronson       10         'Jaakko'
# 3  https://www.metacritic.com/movie/bronson        6          'CapoR'
# 4  https://www.metacritic.com/movie/bronson        8       'OrwellB.'
#
#              dateP                                                Rev  \
# 0   'Apr 25, 2013'   'Many have dismissed this film for not explor...
# 1   'Oct 13, 2009'   'Anyone who doesn t like this movie simply ju...
# 2   'Jul 19, 2012'   'Not sure what to think at this film at first...
# 3   'Oct 13, 2009'   'Nicely portrayed but it lacks the elements t...
# 4   'Oct 10, 2009'   'Bronson is more than entertainment. It is ar...
#
#   thumbsUp thumbsTot   WC  Analytic  Clout  ...  Comma  Colon  SemiC  QMark  \
# ...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 319662 entries, 0 to 319661
# Data columns (total 100 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   url           319662 non-null  str
#  1   idvscore      316258 non-null  object
#  2   reviewer      316255 non-null  str
#  3   dateP         316249 non-null  str
#  4   Rev           316249 non-null  str
#  5   thumbsUp      316082 non-null  object
#  6   thumbsTot     316086 non-null  object
#  7   WC            319662 non-null  int64
#  8   Analytic      319662 non-null  float64
#  9   Clout         319662 non-null  float64
#  10  Authentic     319662 non-null  float64
#  11  Tone          319662 non-null  float64
#  12  WPS           319662 non-null  float64
#  13  Sixltr        319662 non-null  float64
#  14  Dic           319662 non-null  float64
#  15  function      319662 non-null  float64
#  16  pronoun       319662 non-null  float64
# ...

# %%
df['reviewer'].unique
# Out:
# <bound method Series.unique of 0             'Longbottom94'
# 1                  'MartinB'
# 2                   'Jaakko'
# 3                    'CapoR'
# 4                 'OrwellB.'
#                  ...
# 319657             'Zenflar'
# 319658      'juiliopaublito'
# 319659     'PorridgeBoy3000'
# 319660          'jamesfhall'
# 319661            'Motoritz'
# Name: reviewer, Length: 319662, dtype: str>

# %% [markdown]
# Here i took a look at the reviewers names, they all were in square brackets so now i'm gonna remove the square brackets and the extra space on the front

# %%
df['reviewer'] = df['reviewer'].str.strip(" '")
df['reviewer'].unique
# Out:
# <bound method Series.unique of 0            Longbottom94
# 1                 MartinB
# 2                  Jaakko
# 3                   CapoR
# 4                OrwellB.
#                ...
# 319657            Zenflar
# 319658     juiliopaublito
# 319659    PorridgeBoy3000
# 319660         jamesfhall
# 319661           Motoritz
# Name: reviewer, Length: 319662, dtype: str>

# %% [markdown]
# Now i removed all the square brackets. I also saw that for date and Rev there was the same issue, so now i'm gonna remove te square brackets and the extra space for those colomms too.

# %%
df['dateP'] = df['dateP'].str.strip(" '")
df['dateP'].unique
# Out:
# <bound method Series.unique of 0         Apr 25, 2013
# 1         Oct 13, 2009
# 2         Jul 19, 2012
# 3         Oct 13, 2009
# 4         Oct 10, 2009
#               ...
# 319657     Sep 6, 2021
# 319658    Nov 25, 2021
# 319659    Dec 31, 2021
# 319660    Jan 20, 2022
# 319661     Feb 7, 2022
# Name: dateP, Length: 319662, dtype: str>

# %%
df['Rev'] = df['Rev'].str.strip(" '")
df['Rev'].unique
# Out:
# <bound method Series.unique of 0         Many have dismissed this film for not explorin...
# 1         Anyone who doesn t like this movie simply just...
# 2         Not sure what to think at this film at first. ...
# 3         Nicely portrayed but it lacks the elements to ...
# 4         Bronson is more than entertainment. It is art ...
#                                 ...
# 319657    A+A+A+A+A+A+A+A+A+A+A+A+A+A+A+A+A+A+A+A+A+A+A+...
# 319658    in my opinion spirited away is one of the best...
# 319659    Usually I don t like watching movies that much...
# 319660    Studio Ghibli s gripping masterpiece Spirited ...
# 319661    Words cannot describe how amazing this movie i...
# Name: Rev, Length: 319662, dtype: str>

# %% [markdown]
# Here you can see that i removed the square brackets from the reviews.

# %%
df.head()
# Out:
#                                         url idvscore      reviewer  \
# 0  https://www.metacritic.com/movie/bronson        8  Longbottom94
# 1  https://www.metacritic.com/movie/bronson        9       MartinB
# 2  https://www.metacritic.com/movie/bronson       10        Jaakko
# 3  https://www.metacritic.com/movie/bronson        6         CapoR
# 4  https://www.metacritic.com/movie/bronson        8      OrwellB.
#
#           dateP                                                Rev thumbsUp  \
# 0  Apr 25, 2013  Many have dismissed this film for not explorin...        2
# 1  Oct 13, 2009  Anyone who doesn t like this movie simply just...        0
# 2  Jul 19, 2012  Not sure what to think at this film at first. ...        1
# 3  Oct 13, 2009  Nicely portrayed but it lacks the elements to ...        0
# 4  Oct 10, 2009  Bronson is more than entertainment. It is art ...        0
#
#   thumbsTot   WC  Analytic  Clout  ...  Comma  Colon  SemiC  QMark  Exclam  \
# ...

# %%
df.to_csv('UserReviews_cleaned.csv', index=False)
